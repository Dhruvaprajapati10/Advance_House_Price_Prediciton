# %% [markdown]
# <a href="https://colab.research.google.com/github/Arunpandey60/EDA_Advance_House_Price_Prediciton/blob/main/EDA_Advance_House_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## To load csv fiile from local device to google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-13f89221-8dbe-4408-bc59-ab6c8e5beccb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13f89221-8dbe-4408-bc59-ab6c8e5beccb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
dataset.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
## Importing all the library necessary for analysis and viewing dataset
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

dataset = pd.read_csv(io.BytesIO(uploaded['train.csv']))
dataset
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
## Priting shape of dataset with (rows and columns)
print(dataset.shape)
# Out:
# (1460, 81)

# %%
## Printing top 5 records
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # ***In data Analysis We will analyze to find out below mentioned stuff***
#
# 1.   Missing Values
# 2.   Numeric Variables
# 3.   Distribution of Numeric Variables
# 4.   Categorical Variables
# 5.   Outliers
# 6.   Relationship between independent and dependent feature(SalePrice)

# %% [markdown]
# # **Missing** **Value**

# %%
#printing sum of only those columns having missing value
features_with_na = [features for features in dataset.columns if dataset[features].isnull().sum()>1]
for feature in features_with_na:
  print(feature, '-->',np.sum(dataset[feature].isnull()))
# Out:
# LotFrontage --> 259
# Alley --> 1369
# MasVnrType --> 8
# MasVnrArea --> 8
# BsmtQual --> 37
# BsmtCond --> 37
# BsmtExposure --> 38
# BsmtFinType1 --> 37
# BsmtFinType2 --> 38
# FireplaceQu --> 690
# GarageType --> 81
# GarageYrBlt --> 81
# GarageFinish --> 81
# GarageQual --> 81
# GarageCond --> 81
# PoolQC --> 1453
# Fence --> 1179
# MiscFeature --> 1406

# %% [markdown]
# **Since we have many missing values we need to find the relationship between missing value and dependent variable(SalePrice)**

# %%
for feature in features_with_na:
  data = dataset.copy()

  data[feature] = np.where(data[feature].isnull(),1,0)

  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.show()

# %% [markdown]
# **Numeric** **Variables**

# %%
numerical_feature = [feature for feature in dataset.columns if dataset[feature].dtypes != 'O']
print('number of numeric featrues are {}'.format(len(numerical_feature)))
dataset[numerical_feature].head(10)
# Out:
# number of numeric featrues are 38
#    Id  MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450  ...        0       2    2008     208500
# 1   2          20         80.0     9600  ...        0       5    2007     181500
# 2   3          60         68.0    11250  ...        0       9    2008     223500
# 3   4          70         60.0     9550  ...        0       2    2006     140000
# 4   5          60         84.0    14260  ...        0      12    2008     250000
# 5   6          50         85.0    14115  ...      700      10    2009     143000
# 6   7          20         75.0    10084  ...        0       8    2007     307000
# 7   8          60          NaN    10382  ...      350      11    2009     200000
# 8   9          50         51.0     6120  ...        0       4    2008     129900
# 9  10         190         50.0     7420  ...        0       1    2008     118000
#
# [10 rows x 38 columns]

# %%
#Temporal Variable(Datetime Variable)
year_feature = [feature for feature in dataset.columns if 'Year' in feature or 'Yr' in feature]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_feature:
  print(feature,dataset[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
dataset.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('YearSold')
plt.ylabel('Median House Price')
plt.title('House Price vs Year Sold')
# Out:
# Text(0.5, 1.0, 'House Price vs Year Sold')

# %%
for feature in year_feature:
  if feature != 'YrSold':
    data = dataset.copy()
    data[feature] = data['YrSold'] - data[feature]

    plt.scatter(data[feature],data['SalePrice'])
    plt.xlabel(feature)
    plt.ylabel('Sales Price')
    plt.show()

# %%
#numeric feature is of 2 type
#continuous and Discrete feature

discrete_feature = [feature for feature in numerical_feature if len(dataset[feature].unique())< 25 and feature not in year_feature+['id']]
print("total discrete features are {}".format(len(discrete_feature)))
discrete_feature
# Out:
# total discrete features are 17
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
dataset[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  ...  PoolArea  MiscVal  MoSold
# 0          60            7            5  ...         0        0       2
# 1          20            6            8  ...         0        0       5
# 2          60            7            5  ...         0        0       9
# 3          70            7            5  ...         0        0       2
# 4          60            8            5  ...         0        0      12
#
# [5 rows x 17 columns]

# %%
for feature in discrete_feature:
  data = dataset.copy()
  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.xlabel(feature)
  plt.ylabel('Sales Price')
  plt.title(feature)
  plt.show()

# %%
continuous_feature = [feature for feature in dataset[numerical_feature] if feature not in discrete_feature+year_feature+['Id']]
print("Total continuous feature are {}".format(len(continuous_feature)))                                                                                                          
continuous_feature
# Out:
# Total continuous feature are 16
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
# for distribution of continuous value we usually create histogram
for feature in continuous_feature:
  data = dataset.copy()
  data[feature].hist(bins=25)
  plt.xlabel(feature)
  plt.ylabel('Sales Price')
  plt.show()

# %%
# We will use logarithmic transformation to transform the skewed or non-gaussian distribution to Gaussian-distrubution
for feature in continuous_feature:
  data = dataset.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature] = np.log(data[feature])
    data['SalePrice'] = np.log(data['SalePrice'])
    plt.scatter(data[feature],data['SalePrice'])
    plt.xlabel(feature)
    plt.ylabel('Sales Price')
    plt.show()

# %%
#Plotting the outliers in continuous feature
#boxplot does not work for categorical feature so only use for continuous variable
for feature in continuous_feature:
  data = dataset.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature] = np.log(data[feature])
    data.boxplot(column=feature)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()

# %% [markdown]
# **Categorical** **Variable**

# %%
categorical_feature = [feature for feature in dataset.columns if dataset[feature].dtype == 'O' ]
print(f'Total categorical features are {len(categorical_feature)}')
dataset[categorical_feature].head()
# Out:
# Total categorical features are 43
#   MSZoning Street Alley LotShape  ... Fence MiscFeature SaleType SaleCondition
# 0       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 1       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 2       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
# 3       RL   Pave   NaN      IR1  ...   NaN         NaN       WD       Abnorml
# 4       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %%
for feature in categorical_feature:
  print('The feature is {} and number of categories are {}'.format(feature,len(dataset[feature].unique())))
# Out:
# The feature is MSZoning and number of categories are 5
# The feature is Street and number of categories are 2
# The feature is Alley and number of categories are 3
# The feature is LotShape and number of categories are 4
# The feature is LandContour and number of categories are 4
# The feature is Utilities and number of categories are 2
# The feature is LotConfig and number of categories are 5
# The feature is LandSlope and number of categories are 3
# The feature is Neighborhood and number of categories are 25
# The feature is Condition1 and number of categories are 9
# The feature is Condition2 and number of categories are 8
# The feature is BldgType and number of categories are 5
# The feature is HouseStyle and number of categories are 8
# The feature is RoofStyle and number of categories are 6
# The feature is RoofMatl and number of categories are 8
# The feature is Exterior1st and number of categories are 15
# The feature is Exterior2nd and number of categories are 16
# ...

# %%
for feature in categorical_feature:
  data = dataset.copy()
  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.xlabel(feature)
  plt.ylabel('Sales Price')
  plt.title(feature)
  plt.show()
